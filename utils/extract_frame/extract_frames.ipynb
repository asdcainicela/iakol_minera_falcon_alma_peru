# %%
import os
import sys
import cv2
from glob import glob

# %%
#Si no está en colab, puedes ignorar (no comentar)
PATH_COLAB = "/content/drive/MyDrive/Smartech/Basura/extract_frames"

# %%
is_colab = 'google.colab' in sys.modules

if is_colab:
    from google.colab import drive
    drive.mount('/content/drive')
    BASE_PATH = PATH_COLAB
    if os.path.exists(BASE_PATH):
        os.chdir(BASE_PATH)
        print("📂 Ahora trabajando en:", os.getcwd())
    else:
        print(f"Error: The directory '{BASE_PATH}' does not exist. Please verify the path.")
else:
    print("No está en Colab")
# Out:
# Mounted at /content/drive
# 📂 Ahora trabajando en: /content/drive/MyDrive/Smartech/Basura/extract_frames

# %%
def extract_frames(video_path, output_folder, fps=2):
    # Crear la carpeta de salida si no existe
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Cargar el video
    video = cv2.VideoCapture(video_path)

    # Verificar si se abrió correctamente
    if not video.isOpened():
        print(f"No se pudo abrir el video: {video_path}")
        return

    # Obtener la cantidad total de frames y el FPS original del video
    original_fps = int(video.get(cv2.CAP_PROP_FPS))
    frame_count = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calcular el intervalo de frames para extraer
    interval = max(1, int(original_fps / fps))

    frame_number = 0  # Número del frame actual
    extracted_frames = 0  # Contador de frames extraídos

    while True:
        ret, frame = video.read()
        if not ret:  # Salir si no hay más frames
            break

        # Guardar el frame si está en el intervalo
        if frame_number % interval == 0:
            # Generar el nombre de archivo y guardar la imagen
            video_name = os.path.splitext(os.path.basename(video_path))[0]
            view_folder = os.path.basename(os.path.dirname(video_path))
            video_output_folder = f"{view_folder}_{video_name}"
            video_output_folder = os.path.join(output_folder, video_output_folder)
            if not os.path.exists(video_output_folder):
                os.makedirs(video_output_folder)
            output_path = os.path.join(video_output_folder, f"{str(view_folder)}_{str(video_name)}_{extracted_frames:04d}.jpg")
            cv2.imwrite(output_path, frame)  # Guardar el frame
            extracted_frames += 1

        frame_number += 1

    # Liberar el video
    video.release()
    print(f"Se extrajeron {extracted_frames} frames de '{video_path}' y se guardaron en '{video_output_folder}'.")

# %%
"""
Puedes configurar si quieres solo un subdirectorio o varios (leer comentarios)
"""
def process_all_videos(parent_folder, output_folder, fps=4):
    # Buscar todos los archivos de video en la carpeta padre y subcarpetas
    #video_files = glob(os.path.join(parent_folder, "*.mp4"), recursive=True) # solo un nivel
    video_files = glob(os.path.join(parent_folder, "**", "*.mp4"), recursive=True) # varios niveles de subdirectorios

    if not video_files:
        print("No se encontraron archivos de video en la carpeta proporcionada.")
        return

    for video_path in video_files:
        print(f"Procesando video: {video_path}")
        extract_frames(video_path, output_folder, fps=fps)

# %%
output_folder = "data"
parent_folder = "."  # Carpeta padre con videos y subcarpetas
# output_folder = os.path.join(data_folder, parent_folder)
process_all_videos(parent_folder, output_folder, fps=1)
# Out:
# Procesando video: ./videos/01-04-2025 CAM 02 MERCADO ROJO ARROJANDO BASURA EN VIA PUBLICA DE 17.49.21 A 17.49.40/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250401174920_20250401174940.mp4
# Se extrajeron 20 frames de './videos/01-04-2025 CAM 02 MERCADO ROJO ARROJANDO BASURA EN VIA PUBLICA DE 17.49.21 A 17.49.40/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250401174920_20250401174940.mp4' y se guardaron en 'data/01-04-2025 CAM 02 MERCADO ROJO ARROJANDO BASURA EN VIA PUBLICA DE 17.49.21 A 17.49.40_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250401174920_20250401174940'.
# Procesando video: ./videos/01-04-2025 CAM 02-AV SANTA ROSA-ARROJO DE BASURA 093900 A 093930/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250401093859_20250401093929.mp4
# Se extrajeron 30 frames de './videos/01-04-2025 CAM 02-AV SANTA ROSA-ARROJO DE BASURA 093900 A 093930/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250401093859_20250401093929.mp4' y se guardaron en 'data/01-04-2025 CAM 02-AV SANTA ROSA-ARROJO DE BASURA 093900 A 093930_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250401093859_20250401093929'.
# Procesando video: ./videos/01-04-2025 CAM 02 MERCADO ROJO ARROJANDO BASURA EN VIA PUBLICA DE 15.43.04 A 15.43.26/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250401154303_20250401154325.mp4
# Se extrajeron 22 frames de './videos/01-04-2025 CAM 02 MERCADO ROJO ARROJANDO BASURA EN VIA PUBLICA DE 15.43.04 A 15.43.26/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250401154303_20250401154325.mp4' y se guardaron en 'data/01-04-2025 CAM 02 MERCADO ROJO ARROJANDO BASURA EN VIA PUBLICA DE 15.43.04 A 15.43.26_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250401154303_20250401154325'.
# Procesando video: ./videos/01-04-2025 CAM 02-AV SANTA ROSA-ARROJO DE BASURA 091720 A 091745/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250401091719_20250401091744.mp4
# Se extrajeron 25 frames de './videos/01-04-2025 CAM 02-AV SANTA ROSA-ARROJO DE BASURA 091720 A 091745/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250401091719_20250401091744.mp4' y se guardaron en 'data/01-04-2025 CAM 02-AV SANTA ROSA-ARROJO DE BASURA 091720 A 091745_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250401091719_20250401091744'.
# Procesando video: ./videos/01-04-2025 CAM 02-AV SANTA ROSA-ARROJO DE BASURA 084455 A 084555/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250401084454_20250401084554.mp4
# Se extrajeron 60 frames de './videos/01-04-2025 CAM 02-AV SANTA ROSA-ARROJO DE BASURA 084455 A 084555/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250401084454_20250401084554.mp4' y se guardaron en 'data/01-04-2025 CAM 02-AV SANTA ROSA-ARROJO DE BASURA 084455 A 084555_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250401084454_20250401084554'.
# Procesando video: ./videos/03-04-2025 PANORAMICA 01-PLAZA SANTA ROSA-ARROJO DE BASURA/PANORAMICA 1.mp4
# Se extrajeron 42 frames de './videos/03-04-2025 PANORAMICA 01-PLAZA SANTA ROSA-ARROJO DE BASURA/PANORAMICA 1.mp4' y se guardaron en 'data/03-04-2025 PANORAMICA 01-PLAZA SANTA ROSA-ARROJO DE BASURA_PANORAMICA 1'.
# Procesando video: ./videos/02-04-2025 PANORAMICA 02-DOMINICOS-ARROJO DE BASURA 232050 A 232120/PANORAMICA 2/BS-DOMINICOS_PANORAMICA 2 BS-DOMINICOS_20250402232049_20250402232121.mp4
# Se extrajeron 32 frames de './videos/02-04-2025 PANORAMICA 02-DOMINICOS-ARROJO DE BASURA 232050 A 232120/PANORAMICA 2/BS-DOMINICOS_PANORAMICA 2 BS-DOMINICOS_20250402232049_20250402232121.mp4' y se guardaron en 'data/PANORAMICA 2_BS-DOMINICOS_PANORAMICA 2 BS-DOMINICOS_20250402232049_20250402232121'.
# Procesando video: ./videos/02-04-2025 CAM 02 MERCADO ROJO ARROJANDO BASURA EN VIA PUBLICA DE 16.07.47 A 16.09.10/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250402160747_20250402160910.mp4
# Se extrajeron 84 frames de './videos/02-04-2025 CAM 02 MERCADO ROJO ARROJANDO BASURA EN VIA PUBLICA DE 16.07.47 A 16.09.10/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250402160747_20250402160910.mp4' y se guardaron en 'data/02-04-2025 CAM 02 MERCADO ROJO ARROJANDO BASURA EN VIA PUBLICA DE 16.07.47 A 16.09.10_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250402160747_20250402160910'.
# Procesando video: ./videos/03-04-2025 CAM 01-PLAZA SANTA ROSA-ARROJO DE BASURA/Video_20250403163431/BS-CHUCUITO_CAM 1 BS-CHUCUITO_20250403010218_20250403010355.mp4
# Se extrajeron 97 frames de './videos/03-04-2025 CAM 01-PLAZA SANTA ROSA-ARROJO DE BASURA/Video_20250403163431/BS-CHUCUITO_CAM 1 BS-CHUCUITO_20250403010218_20250403010355.mp4' y se guardaron en 'data/Video_20250403163431_BS-CHUCUITO_CAM 1 BS-CHUCUITO_20250403010218_20250403010355'.
# Procesando video: ./videos/02-04-2025 CAM 02 MERCADO ROJO ARROJANDO BASURA EN VIA PUBLICA DE 18.09.25 A 18.10.13/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250402180925_20250402181013.mp4
# Se extrajeron 49 frames de './videos/02-04-2025 CAM 02 MERCADO ROJO ARROJANDO BASURA EN VIA PUBLICA DE 18.09.25 A 18.10.13/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250402180925_20250402181013.mp4' y se guardaron en 'data/02-04-2025 CAM 02 MERCADO ROJO ARROJANDO BASURA EN VIA PUBLICA DE 18.09.25 A 18.10.13_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250402180925_20250402181013'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 153320 A 153340/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316153319_20250316153339.mp4
# Se extrajeron 20 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 153320 A 153340/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316153319_20250316153339.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 153320 A 153340_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316153319_20250316153339'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 152445 A 152515/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316152445_20250316152515.mp4
# Se extrajeron 30 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 152445 A 152515/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316152445_20250316152515.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 152445 A 152515_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316152445_20250316152515'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 173745 173950/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316173745_20250316173950.mp4
# Se extrajeron 125 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 173745 173950/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316173745_20250316173950.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 173745 173950_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316173745_20250316173950'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 172930 A 173245/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316172930_20250316173245.mp4
# Se extrajeron 195 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 172930 A 173245/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316172930_20250316173245.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 172930 A 173245_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316172930_20250316173245'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 154545 A 154955/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316154544_20250316154954.mp4
# Se extrajeron 250 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 154545 A 154955/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316154544_20250316154954.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 154545 A 154955_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316154544_20250316154954'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 155615 A 160000/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316155614_20250316160001.mp4
# Se extrajeron 227 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 155615 A 160000/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316155614_20250316160001.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 155615 A 160000_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316155614_20250316160001'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 160315 A 160345/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316160315_20250316160345.mp4
# Se extrajeron 30 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 160315 A 160345/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316160315_20250316160345.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 160315 A 160345_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316160315_20250316160345'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 160655 A 160945/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316160655_20250316160945.mp4
# Se extrajeron 170 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 160655 A 160945/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316160655_20250316160945.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 160655 A 160945_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316160655_20250316160945'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 161125 A 161240/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316161125_20250316161240.mp4
# Se extrajeron 75 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 161125 A 161240/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316161125_20250316161240.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 161125 A 161240_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316161125_20250316161240'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 161415 A 161545/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316161415_20250316161545.mp4
# Se extrajeron 90 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 161415 A 161545/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316161415_20250316161545.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 161415 A 161545_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316161415_20250316161545'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 161820 A 161850/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316161820_20250316161850.mp4
# Se extrajeron 30 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 161820 A 161850/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316161820_20250316161850.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 161820 A 161850_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316161820_20250316161850'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 163755 A 163825/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316163754_20250316163824.mp4
# Se extrajeron 30 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 163755 A 163825/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316163754_20250316163824.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 163755 A 163825_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316163754_20250316163824'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 164310 A 164345/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316164309_20250316164344.mp4
# Se extrajeron 35 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 164310 A 164345/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316164309_20250316164344.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 164310 A 164345_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316164309_20250316164344'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 164522 A 164550/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316164521_20250316164549.mp4
# Se extrajeron 29 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 164522 A 164550/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316164521_20250316164549.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 164522 A 164550_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316164521_20250316164549'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 165110 A 165315/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316165109_20250316165314.mp4
# Se extrajeron 125 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 165110 A 165315/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316165109_20250316165314.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 165110 A 165315_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316165109_20250316165314'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 170020 A 170135/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316170019_20250316170134.mp4
# Se extrajeron 75 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 170020 A 170135/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316170019_20250316170134.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 170020 A 170135_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316170019_20250316170134'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 170600 A 170650/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316170600_20250316170650.mp4
# Se extrajeron 50 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 170600 A 170650/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316170600_20250316170650.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 170600 A 170650_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316170600_20250316170650'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 170845 A 170940/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316170845_20250316170940.mp4
# Se extrajeron 55 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 170845 A 170940/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316170845_20250316170940.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 170845 A 170940_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316170845_20250316170940'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 171205 A 171240/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316171205_20250316171240.mp4
# Se extrajeron 35 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 171205 A 171240/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316171205_20250316171240.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 171205 A 171240_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316171205_20250316171240'.
# Procesando video: ./videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 172620 A 172720/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316172620_20250316172720.mp4
# Se extrajeron 60 frames de './videos/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 172620 A 172720/BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316172620_20250316172720.mp4' y se guardaron en 'data/16-03-2025 CAM 02-AV. SANTA ROSA-ARROJO DE BASURA 172620 A 172720_BS-MERCADO-ROJO_CAM 2 BS-MERCADO-ROJO_20250316172620_20250316172720'.
